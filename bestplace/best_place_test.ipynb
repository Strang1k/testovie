# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("attention_details.xlsx", None)
df.keys()
# Out:
# C:\Users\AACE~1\AppData\Local\Temp/ipykernel_10516/3302207274.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   df = pd.read_excel("attention_details.xlsx", None)
# dict_keys(['Справочник точек', 'Выручка по обучающей выборке'])

# %%
df = pd.read_excel('attention_details.xlsx', 'Справочник точек')
# Out:
# C:\Users\AACE~1\AppData\Local\Temp/ipykernel_10516/1317411235.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   df = pd.read_excel('attention_details.xlsx', 'Справочник точек')

# %%
df['Заполненность ТЦ'] = df['Заполненность ТЦ'].fillna(5.0)

# %%
df['Заполненность ТЦ'].value_counts()
# Out:
# 3.0    121
# 5.0     64
# 2.0     35
# 1.0     17
# 0.0      9
# Name: Заполненность ТЦ, dtype: int64

# %%
df['Заполненность ТЦ'].count()
# Out:
# 246

# %%
df
# Out:
#       id точки                                              Адрес      Широта  \
# 0       8955.0   Оренбургская обл, Оренбург г, Шарлыкское ш, д...   55.118272
# 1      11007.0  Алтайский край, г. Барнаул, ул. Малахова, дом ...   83.696799
# 2      11366.0  Амурская область, Благовещенск, улица Мухина, 114  127.510357
# 3      11810.0  Архангельская обл, г. Архангельск , Троицкий п...   40.528249
# 4      15041.0  Архангельская обл, г. Архангельск, Троицкий пр...   40.526317
# ..         ...                                                ...         ...
# 241  2633929.0  Ямало-Ненецкий АО, г. Новый Уренгой, ул. Сибир...   76.631279
# 242  2633930.0  Ямало-Ненецкий АО, Ноябрьск г, Советская ул, д...   75.465427
# 243  2633935.0  Ярославская обл, г. Ярославль, ул. Победы, дом...   39.869236
# 244  2633946.0  Ярославская обл, г. Ярославль, ул. Свободы, до...   39.883707
# 245  2633948.0  Ярославская обл, Ярославский район, Телегински...   39.783545
#
# ...

# %%
df['Парковка'].value_counts()
# Out:
# бесплатная парковка    156
# нет парковки            34
# платная парковка        31
# 100                      2
# 1000                     1
# 700                      1
# бесплатная паpковка      1
# Name: Парковка, dtype: int64

# %%
import re

# %%
re.sub('	', ', ', '42706	42192	18931	42122	42383	42156	42388	42204	42340	42546')
# Out:
# '42706, 42192, 18931, 42122, 42383, 42156, 42388, 42204, 42340, 42546'

# %%
xl = pd.ExcelFile('attention_details.xlsx')

xl.sheet_names  # see all sheet names
# Out:
# ['Справочник точек', 'Выручка по обучающей выборке']

# %%
xl.parse('Выручка по обучающей выборке')  # read a specific sheet to DataFrame
# Out:
#       id точки     2015-01-01     2015-02-01     2015-03-01     2015-04-01  \
# 0      11366.0  245709.342667  301024.685000  406199.782258  295602.853000
# 1      11810.0  270245.842066  297964.820199  406198.175918  232433.263996
# 2      15041.0  171972.976000  198141.440000  260215.741935  205316.010644
# 3      15775.0  409032.989736  468816.460949  582717.510920  442807.529886
# 4      16102.0  437693.191667  510077.198214  602107.617742  465779.798333
# ..         ...            ...            ...            ...            ...
# 150  2634000.0  341009.722000  413489.085501  518426.278387  376071.505667
# 151  2634008.0  270923.715000  404737.144643  470433.872222  401063.781000
# 152  2634011.0  378429.753517  350607.477988  482925.193552  367225.245935
# 153  2633936.0            NaN            NaN            NaN            NaN
# 154        NaN            NaN            NaN            NaN            NaN
#
#         2015-05-01     2015-06-01     2015-07-01     2015-08-01  \
# ...

# %%
df.keys()
# Out:
# Index(['id точки', 'Адрес', 'Широта', 'Долгота', 'Дата открытия',
#        'Дата закрытия', 'Площадь магазина', 'Тип входа', 'Площадь ТЦ',
#        'Формат магазина', 'Парковка', 'Этаж', 'Время работы',
#        'Заполненность ТЦ', 'Рядом с эскалатором', 'Рядом со входом',
#        'Конкуренты в ТЦ', 'Расположение в ТЦ', 'Толока', 'Люкс', 'Выборка'],
#       dtype='object')

# %%
df = pd.read_excel("attention_details.xlsx", 'Выручка по обучающей выборке', dtype='object')

# %%
df.isna()
# Out:
#      id точки  2015-01-01  2015-02-01  2015-03-01  2015-04-01  2015-05-01  \
# 0       False       False       False       False       False       False
# 1       False       False       False       False       False       False
# 2       False       False       False       False       False       False
# 3       False       False       False       False       False       False
# 4       False       False       False       False       False       False
# ..        ...         ...         ...         ...         ...         ...
# 150     False       False       False       False       False       False
# 151     False       False       False       False       False       False
# 152     False       False       False       False       False       False
# 153     False        True        True        True        True       False
# 154      True        True        True        True        True        True
#
#      2015-06-01  2015-07-01  2015-08-01  2015-09-01  ...  2018-01-01  \
# ...

# %%
np.where(df.isna() == True)[0]
# Out:
# array([  4,   4,   4,   4,   7,   7,  32,  32,  32,  49,  53,  53,  53,
#         53,  58,  65,  76,  76,  82,  82,  90,  90, 108, 108, 108, 108,
#        108, 108, 108, 108, 108, 108, 108, 108, 108, 108, 108, 108, 108,
#        108, 108, 108, 108, 108, 108, 108, 108, 108, 108, 108, 108, 108,
#        108, 108, 108, 108, 108, 108, 108, 108, 108, 108, 108, 108, 108,
#        108, 108, 108, 108, 109, 109, 109, 109, 109, 109, 109, 109, 109,
#        109, 109, 114, 114, 114, 114, 114, 114, 114, 115, 115, 115, 115,
#        115, 115, 115, 115, 116, 116, 116, 116, 116, 116, 116, 116, 116,
#        116, 116, 117, 117, 117, 117, 117, 117, 117, 117, 117, 117, 118,
#        118, 118, 118, 118, 118, 118, 118, 118, 118, 118, 119, 119, 119,
#        119, 119, 119, 119, 119, 119, 119, 119, 120, 120, 120, 120, 120,
#        120, 120, 120, 120, 120, 120, 121, 121, 121, 121, 121, 121, 121,
#        121, 121, 121, 121, 122, 122, 122, 122, 122, 122, 122, 122, 122,
# ...

# %%
df['id точки'].duplicated().value_counts()
# Out:
# False    151
# True       4
# Name: id точки, dtype: int64

# %%
[list(np.where(df['id точки'].duplicated() == True))]
# Out:
# [[array([ 84, 111, 129, 154], dtype=int64)]]

# %%
df['id точки'].iloc[list(np.where(df['id точки'].duplicated() == True))[0]]
# Out:
# 84     42383.0
# 111    42597.0
# 129        NaN
# 154        NaN
# Name: id точки, dtype: float64

# %%
df['id точки'][4]
# Out:
# 16102.0

# %%
idt = []

# %%
x = df['id точки'].iloc[list(np.where(df.isna() == True)[0])]

# %%
x.unique()
# Out:
# array([  16102.,   17983.,   42001.,   42132.,   42179.,   42201.,
#          42238.,   42319.,   42379.,   42438.,      nan,   42590.,
#          42637.,   45801.,   42665.,   42072.,   42678.,   42680.,
#          42681.,   42683.,   42689.,   42691.,   42694.,   42696.,
#          42712.,   42720.,   42722.,   42730.,   42732.,   42733.,
#          42738.,   42743.,   42745.,   42758.,   42775.,   42777.,
#          42790.,   42792.,   42800.,   42803.,   42822.,   42826.,
#          42827.,   42831.,   42840.,   42847., 2633936.])

# %%
for id in x.unique():
    idt.append(str(id))

s = ', '.join(str(x) for x in idt)

# %%
re.sub('.0,', ',', s)[:-2]
# Out:
# '16102, 17983, 42001, 42132, 42179, 42201, 42238, 42319, 42379, 42438, nan, 42590, 42637, 45801, 42665, 42072, 42678, 42680, 42681, 42683, 42689, 42691, 42694, 42696, 42712, 42720, 42722, 42730, 42732, 42733, 42738, 42743, 42745, 42758, 42775, 42777, 42790, 42792, 42800, 42803, 42822, 42826, 42827, 42831, 42840, 42847, 2633936, 16102, 17983, 42001, 42132, 42179, 42201, 42238, 42319, 42379, 42438, nan, 42590, 42637, 45801, 42665, 42072, 42678, 42680, 42681, 42683, 42689, 42691, 42694, 42696, 42712, 42720, 42722, 42730, 42732, 42733, 42738, 42743, 42745, 42758, 42775, 42777, 42790, 42792, 42800, 42803, 42822, 42826, 42827, 42831, 42840, 42847, 2633936, 16102, 17983, 42001, 42132, 42179, 42201, 42238, 42319, 42379, 42438, nan, 42590, 42637, 45801, 42665, 42072, 42678, 42680, 42681, 42683, 42689, 42691, 42694, 42696, 42712, 42720, 42722, 42730, 42732, 42733, 42738, 42743, 42745, 42758, 42775, 42777, 42790, 42792, 42800, 42803, 42822, 42826, 42827, 42831, 42840, 42847, 2633936'

# %%
for x in df.keys():
    print(np.where(df[x] < 5000))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\AACE~1\AppData\Local\Temp/ipykernel_12480/2556485924.py in <module>
#       1 for x in df.keys():
# ----> 2     print(np.where(df[x] < 5000))
#
# c:\Games\Code\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# c:\Games\Code\lib\site-packages\pandas\core\arraylike.py in __lt__(self, other)
#      38     @unpack_zerodim_and_defer("__lt__")
#      39     def __lt__(self, other):
# ---> 40         return self._cmp_method(other, operator.lt)
#      41
# ...

# %%
df.keys()
# Out:
# Index(['id точки', '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#        '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01', '2015-09-01',
#        '2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01', '2016-02-01',
#        '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01', '2016-07-01',
#        '2016-08-01', '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01',
#        '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01',
#        '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01',
#        '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01', '2018-04-01',
#        '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01',
#        '2018-10-01', '2018-11-01'],
#       dtype='object')

# %%
df = pd.read_excel('attention_details.xlsx', 'Справочник точек')
# Out:
# C:\Users\AACE~1\AppData\Local\Temp/ipykernel_15620/1317411235.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})
#   df = pd.read_excel('attention_details.xlsx', 'Справочник точек')

# %%
df1 = pd.read_excel('attention_details.xlsx', 'Выручка по обучающей выборке')

# %%
set(df1['id точки']) - set(df['id точки']) #отличающиеся значения из 2 листа, которого нет в первом
# Out:
# {nan, nan, 2633921.0, nan, 45801.0, 2633936.0, 2634000.0, 2634008.0, 2634011.0}

# %%
#df.query()

# %%
df['Формат магазина'].value_counts()
# Out:
# ТЦ         191
# Мини ТЦ     28
# Street      18
# Стрит        4
# Мини-ТЦ      3
# Strееt       1
# Стрт         1
# Name: Формат магазина, dtype: int64

# %%
mt1 = df['id точки'].iloc[list(np.where(df['Формат магазина'] == 'Мини-ТЦ'))[0]]

# %%
MT = df['id точки'].iloc[list(np.where(df['Формат магазина'] == 'Мини ТЦ'))[0]]

# %%
mt1 = pd.DataFrame(mt1)
MT = pd.DataFrame(MT);

# %%
print(mt1.count(), MT.count())
# Out:
# id точки    3
# dtype: int64 id точки    27
# dtype: int64

# %%
MT = MT.append(mt1, ignore_index=True)

# %%
MT.count()
# Out:
# id точки    30
# dtype: int64

# %%
MT.head(5)
# Out:
#    id точки
# 0   18331.0
# 1   18728.0
# 2   41824.0
# 3   41933.0
# 4   42039.0

# %%
df1.head(5)
# Out:
#    id точки     2015-01-01     2015-02-01     2015-03-01     2015-04-01  \
# 0   11366.0  245709.342667  301024.685000  406199.782258  295602.853000
# 1   11810.0  270245.842066  297964.820199  406198.175918  232433.263996
# 2   15041.0  171972.976000  198141.440000  260215.741935  205316.010644
# 3   15775.0  409032.989736  468816.460949  582717.510920  442807.529886
# 4   16102.0  437693.191667  510077.198214  602107.617742  465779.798333
#
#       2015-05-01     2015-06-01     2015-07-01     2015-08-01     2015-09-01  \
# 0  268179.172258  266579.009667  202667.039355  207347.022581  237393.216667
# 1  229317.708387  251403.308057  242000.555806  260407.109247  267051.162996
# 2  187059.870968  198590.970667  178250.637781  187094.699355  211000.005517
# 3  371689.316054  428430.990000  365894.971255  384266.496739  385515.509997
# 4  423448.914516  414476.575000  370944.770968  392089.754839  416797.330000
#
#    ...     2018-01-01     2018-02-01     2018-04-01     2018-05-01  \
# ...

# %%
df1['id точки'].astype(float)
MT['id точки'].astype(float);

# %%
MT = MT.reset_index(drop=True)

# %%
df1 = df1.reset_index(drop=True)

# %%
df1 = df1.fillna(0)

# %%
MT = MT.fillna(0)

# %%
type(df1['id точки']) == type(MT['id точки'])
# Out:
# True

# %%
spisok = []

for each in list(MT['id точки']):
    for ea in (list(df1['id точки'])):
        if each == ea:
            spisok.append(each)

# %%
dff = df1.loc[df1['id точки'].isin(spisok)]

# %%
dff = dff.reset_index(drop = True)

# %%
dff = dff.drop(np.where( dff['id точки'] == 0 )[0])

# %%
dff = dff.reset_index(drop = True)

# %%
dff.head(5)
# Out:
#    id точки     2015-01-01     2015-02-01     2015-03-01     2015-04-01  \
# 0   18728.0  337679.020000  505983.520415  615360.263226  500352.832000
# 1   41824.0  294160.860000  332418.278571  420586.925516  343592.490000
# 2   41933.0  109865.820000  126723.117857  152200.364516  107882.820000
# 3   42067.0  628606.145983  782399.429996  951061.128761  656418.923765
# 4   42192.0  151637.321333  216306.985000  277075.327097  180022.309333
#
#       2015-05-01     2015-06-01     2015-07-01     2015-08-01     2015-09-01  \
# 0  425920.356129  430724.373333  375469.775484  393728.196129  424960.032000
# 1  304774.200000  286569.600000  276055.519355  281996.941935  318999.450000
# 2   91019.583871   99189.210000   95974.809677   97722.667742   99790.740000
# 3  609605.233548  592214.616000  530772.236125  563528.496872  586790.106000
# 4  170645.389032  196597.060667  176633.319355  194029.565806  204538.501333
#
#    ...     2018-01-01     2018-02-01     2018-04-01     2018-05-01  \
# ...

# %%
dff.iloc[:, 1:].head(5) #без id точки
# Out:
#       2015-01-01     2015-02-01     2015-03-01     2015-04-01     2015-05-01  \
# 0  337679.020000  505983.520415  615360.263226  500352.832000  425920.356129
# 1  294160.860000  332418.278571  420586.925516  343592.490000  304774.200000
# 2  109865.820000  126723.117857  152200.364516  107882.820000   91019.583871
# 3  628606.145983  782399.429996  951061.128761  656418.923765  609605.233548
# 4  151637.321333  216306.985000  277075.327097  180022.309333  170645.389032
#
#       2015-06-01     2015-07-01     2015-08-01     2015-09-01     2015-10-01  \
# 0  430724.373333  375469.775484  393728.196129  424960.032000  440228.572903
# 1  286569.600000  276055.519355  281996.941935  318999.450000  320237.593548
# 2   99189.210000   95974.809677   97722.667742   99790.740000  110064.425806
# 3  592214.616000  530772.236125  563528.496872  586790.106000  608191.066452
# 4  196597.060667  176633.319355  194029.565806  204538.501333  202785.031613
#
# ...

# %%
dff = dff.applymap(lambda i:float(str(i).replace(' ','').replace(',','.')))

# %%
x = [col for col in dff if col.startswith('2016')] #выбираем все колонки соответствующие 2016 году

# %%
#dff = dff.apply(pd.to_numeric)

# %%
x = np.mean(dff.loc[:, x], axis=1) #среднее за все годы

# %%
x
# Out:
# 0     481776.044672
# 1     351137.733872
# 2     124619.623706
# 3     716570.217126
# 4     199417.001653
# 5     190556.625313
# 6     305684.769187
# 7     138701.666531
# 8     676286.677885
# 9     299932.384154
# 10    527666.219130
# 11    242316.209749
# 12    313834.884822
# 13    317714.275262
# 14    253677.551800
# 15    355028.557867
# 16    129228.335985
# 17    168900.883198
# 18    319403.659765
# 19         0.000000
# dtype: float64

# %%
np.mean(x)
# Out:
# 305622.6660838102
